# %%
try:
    num1=int(input("enter a number1:"))
    num2=int(input("Eneter a number 2:"))
    result=num1/num2
except ZeroDivisionError:
    print("Error :you cannot divided by 0")
except ValueError:
    print("Error :Please enter numeric value")
else:
    print("Result:",result)
finally:
    print("end program")
# Out:
# enter a number1: 3
# Eneter a number 2: h
# Error :Please enter numeric value
# end program
